# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder

# %%
# Import dataset
df = pd.read_csv(r"C:\Users\fecez\Downloads\archive (1)\netflix_titles.csv")

# Observe dataset
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# Inspect dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Check for null values
df.isna().sum()
# Out:
# show_id                     0
# type                        0
# title                       0
# director                    0
# cast                        0
# country                     0
# date_added                  0
# release_year                0
# rating                      0
# duration                    0
# listed_in                   0
# description                 0
# index_imdb_x                0
# id_imdb_x                   0
# title_imdb_x                0
# type_imdb_x                 0
# description_imdb_x          0
# release_year_imdb_x         0
# age_certification_imdb_x    0
# runtime_imdb_x              0
# imdb_id_imdb_x              0
# imdb_score_imdb_x           0
# imdb_votes_imdb_x           0
# index_imdb_y                0
# id_imdb_y                   0
# title_imdb_y                0
# type_imdb_y                 0
# description_imdb_y          0
# release_year_imdb_y         0
# age_certification_imdb_y    0
# runtime_imdb_y              0
# imdb_id_imdb_y              0
# imdb_score_imdb_y           0
# imdb_votes_imdb_y           0
# dtype: int64

# %%
df[df.country.isna()].head()
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, index_imdb_x, id_imdb_x, title_imdb_x, type_imdb_x, description_imdb_x, release_year_imdb_x, age_certification_imdb_x, runtime_imdb_x, imdb_id_imdb_x, imdb_score_imdb_x, imdb_votes_imdb_x, index_imdb_y, id_imdb_y, title_imdb_y, type_imdb_y, description_imdb_y, release_year_imdb_y, age_certification_imdb_y, runtime_imdb_y, imdb_id_imdb_y, imdb_score_imdb_y, imdb_votes_imdb_y]
# Index: []
#
# [0 rows x 34 columns]

# %%
imdb = pd.read_csv(r"C:\Users\fecez\Downloads\archive\Netflix TV Shows and Movies.csv", low_memory=False)
imdb.head()
# Out:
#    index        id                            title   type  \
# 0      0   tm84618                      Taxi Driver  MOVIE
# 1      1  tm127384  Monty Python and the Holy Grail  MOVIE
# 2      2   tm70993                    Life of Brian  MOVIE
# 3      3  tm190788                     The Exorcist  MOVIE
# 4      4   ts22164     Monty Python's Flying Circus   SHOW
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  King Arthur, accompanied by his squire, recrui...          1975
# 2  Brian Cohen is an average young Jewish man, bu...          1979
# 3  12-year-old Regan MacNeil begins to adapt an e...          1973
# 4  A British sketch comedy series with the shows ...          1969
#
#   age_certification  runtime    imdb_id  imdb_score  imdb_votes
# 0                 R      113  tt0075314         8.3    795222.0
# 1                PG       91  tt0071853         8.2    530877.0
# 2                 R       94  tt0079470         8.0    392419.0
# 3                 R      133  tt0070047         8.1    391942.0
# 4             TV-14       30  tt0063929         8.8     72895.0

# %%
imdb[imdb['release_year'].astype(str).str.contains(' ')]
# Out:
# Empty DataFrame
# Columns: [index, id, title, type, description, release_year, age_certification, runtime, imdb_id, imdb_score, imdb_votes]
# Index: []

# %%
imdb.loc[imdb['release_year'].astype(str).str.contains(' '), 'release_year'] = imdb.loc[imdb['release_year'].astype(str).str.contains(' '), 'release_year'].astype(str).str.split(' ', n=1).str[-1]

# %%
df.release_year = pd.to_datetime(df['release_year'], format='%Y').dt.year
imdb.release_year = pd.to_datetime(imdb['release_year'], format='%Y').dt.year

# %%
imdb = imdb.drop_duplicates(subset=['title', 'release_year'])

# %%
df = df.merge(imdb.add_suffix('_imdb'), how='left', left_on=['title','release_year'], right_on=['title_imdb','release_year_imdb'])

# %%
df
# Out:
#     show_id   type                                     title         director  \
# 0       s10  Movie                              The Starling   Theodore Melfi
# 1       s28  Movie                                 Grown Ups     Dennis Dugan
# 2       s29  Movie                                Dark Skies    Scott Stewart
# 3       s39  Movie                       Birth of the Dragon     George Nolfi
# 4       s57  Movie  Naruto Shippuden the Movie: Blood Prison  Masahiko Murata
# ..      ...    ...                                       ...              ...
# 762   s8421  Movie                The Men Who Stare at Goats     Grant Heslov
# 763   s8487  Movie                                  The Ring   Gore Verbinski
# 764   s8512  Movie                        The Social Network    David Fincher
# 765   s8707  Movie                            We the Animals   Jeremiah Zagar
# 766   s8758  Movie                        World Trade Center     Oliver Stone
#
#                                                   cast  \
# 0    Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 1    Adam Sandler, Kevin James, Chris Rock, David S...
# 2    Keri Russell, Josh Hamilton, J.K. Simmons, Dak...
# 3    Billy Magnussen, Ron Yuan, Qu Jingjing, Terry ...
# 4    Junko Takeuchi, Chie Nakamura, Rikiya Koyama, ...
# ..                                                 ...
# 762  George Clooney, Ewan McGregor, Jeff Bridges, K...
# 763  Naomi Watts, Martin Henderson, David Dorfman, ...
# 764  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 765  Evan Rosado, Josiah Gabriel, Isaiah Kristian, ...
# 766  Nicolas Cage, Michael Peña, Maggie Gyllenhaal,...
#
#                            country          date_added  release_year rating  \
# 0                    United States  September 24, 2021          2021  PG-13
# 1                    United States  September 20, 2021          2010  PG-13
# 2                    United States  September 19, 2021          2013  PG-13
# 3     China, Canada, United States  September 16, 2021          2017  PG-13
# 4                            Japan  September 15, 2021          2011  TV-14
# ..                             ...                 ...           ...    ...
# 762  United States, United Kingdom        June 4, 2019          2009      R
# 763                  United States     January 1, 2020          2002  PG-13
# 764                  United States       April 1, 2020          2010  PG-13
# 765                  United States   February 11, 2019          2018      R
# 766                  United States   November 20, 2019          2006  PG-13
#
#     duration  ...    id_imdb                                title_imdb  \
# 0    104 min  ...  tm1021871                              The Starling
# 1    103 min  ...    tm93055                                 Grown Ups
# 2     97 min  ...   tm175843                                Dark Skies
# 3     96 min  ...   tm244519                       Birth of the Dragon
# 4    102 min  ...   tm177044  Naruto Shippuden the Movie: Blood Prison
# ..       ...  ...        ...                                       ...
# 762   94 min  ...   tm147211                The Men Who Stare at Goats
# 763  116 min  ...   tm109304                                  The Ring
# 764  121 min  ...    tm86803                        The Social Network
# 765   93 min  ...   tm370232                            We the Animals
# 766  129 min  ...    tm36644                        World Trade Center
#
#      type_imdb                                   description_imdb  \
# 0        MOVIE  After Lilly suffers a loss, a combative Starli...
# 1        MOVIE  After their high school basketball coach passe...
# 2        MOVIE  From the producers of Paranormal Activity, Ins...
# 3        MOVIE  Set against the backdrop of San Franciscoâ€™s ...
# 4        MOVIE  After his capture for attempted assassination ...
# ..         ...                                                ...
# 762      MOVIE  A reporter in Iraq might just have the story o...
# 763      MOVIE  Rachel Keller is a journalist investigating a ...
# 764      MOVIE  The tale of a new breed of cultural insurgent:...
# 765      MOVIE  Manny, Joel and Jonah tear their way through c...
# 766      MOVIE  Two police officers struggle to survive when t...
#
#     release_year_imdb age_certification_imdb runtime_imdb  imdb_id_imdb  \
# 0                2021                  PG-13          102     tt5164438
# 1                2010                  PG-13          102     tt1375670
# 2                2013                  PG-13           97     tt4190332
# 3                2017                  PG-13          120     tt2720826
# 4                2011                  PG-13          108     tt1999167
# ..                ...                    ...          ...           ...
# 762              2009                      R           94     tt1234548
# 763              2002                  PG-13          111     tt0298130
# 764              2010                  PG-13          121     tt1285016
# 765              2018                      R           94     tt7681824
# 766              2006                  PG-13          129     tt0469641
#
#     imdb_score_imdb  imdb_votes_imdb
# 0               6.3          11733.0
# 1               5.9         247229.0
# 2               6.3          75139.0
# 3               5.6           8112.0
# 4               7.1           5021.0
# ..              ...              ...
# 762             6.2         131564.0
# 763             7.1         341888.0
# 764             7.8         681286.0
# 765             6.9           4181.0
# 766             6.0          83129.0
#
# [767 rows x 45 columns]

# %%
df.dropna(inplace=True)

# %%
df
# Out:
# 3                2017                  PG-13          120     tt2720826
# 4                2011                  PG-13          108     tt1999167
# ..                ...                    ...          ...           ...
# 762              2009                      R           94     tt1234548
# 763              2002                  PG-13          111     tt0298130
# 764              2010                  PG-13          121     tt1285016
# 765              2018                      R           94     tt7681824
# 766              2006                  PG-13          129     tt0469641
#
#     imdb_score_imdb  imdb_votes_imdb
# 0               6.3          11733.0
# 1               5.9         247229.0
# 2               6.3          75139.0
# 3               5.6           8112.0
# 4               7.1           5021.0
# ..              ...              ...
# 762             6.2         131564.0
# 763             7.1         341888.0
# 764             7.8         681286.0
# 765             6.9           4181.0
# 766             6.0          83129.0
#
# [767 rows x 45 columns]

# %%
country_distribution = df['country'].value_counts()
print(country_distribution)
# Out:
# United States                                   311
# India                                           151
# United Kingdom, United States                    18
# Turkey                                           17
# Japan                                            14
#                                                ...
# United States, Canada, United Kingdom             1
# United States, United Kingdom, Canada, China      1
# United States, Belgium, Canada, France            1
# Hong Kong, Iceland, United States                 1
# United States, Germany, Mexico                    1
# Name: country, Length: 148, dtype: int64

# %%
type_distribution = df['type'].value_counts()
print(type_distribution)
# Out:
# Movie      724
# TV Show     43
# Name: type, dtype: int64

# %%
release_year_counts = df['release_year'].value_counts().sort_index()
print(release_year_counts)
# Out:
# 1964      1
# 1967      1
# 1972      1
# 1975      1
# 1979      1
# 1980      2
# 1984      1
# 1987      1
# 1991      2
# 1992      1
# 1993      5
# 1994      2
# 1995      2
# 1996      3
# 1997      1
# 1998      5
# 2000      1
# 2001      6
# 2002      3
# 2003      5
# 2004     10
# 2005      5
# 2006     11
# 2007     13
# 2008     17
# 2009     22
# 2010     23
# 2011     24
# 2012     25
# 2013     28
# 2014     39
# 2015     46
# 2016     56
# 2017     74
# 2018    111
# 2019     81
# 2020     98
# 2021     39
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(8, 5))
type_distribution.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Titles by Type')
plt.show()

# %%
plt.figure(figsize=(12, 6))
release_year_counts.plot(kind='line', marker='o', color='purple')
plt.ylabel('Number of Titles')
plt.title('Number of Titles Released Each Year')
plt.grid(True)
plt.show()

# %%
#checking for missing values
print(df.isna().sum())
# Out:
# show_id                     0
# type                        0
# title                       0
# director                    0
# cast                        0
# country                     0
# date_added                  0
# release_year                0
# rating                      0
# duration                    0
# listed_in                   0
# description                 0
# index_imdb_x                0
# id_imdb_x                   0
# title_imdb_x                0
# type_imdb_x                 0
# description_imdb_x          0
# release_year_imdb_x         0
# age_certification_imdb_x    0
# runtime_imdb_x              0
# imdb_id_imdb_x              0
# imdb_score_imdb_x           0
# imdb_votes_imdb_x           0
# index_imdb_y                0
# id_imdb_y                   0
# title_imdb_y                0
# type_imdb_y                 0
# description_imdb_y          0
# release_year_imdb_y         0
# age_certification_imdb_y    0
# runtime_imdb_y              0
# imdb_id_imdb_y              0
# imdb_score_imdb_y           0
# imdb_votes_imdb_y           0
# index_imdb                  0
# id_imdb                     0
# title_imdb                  0
# type_imdb                   0
# description_imdb            0
# release_year_imdb           0
# age_certification_imdb      0
# runtime_imdb                0
# imdb_id_imdb                0
# imdb_score_imdb             0
# imdb_votes_imdb             0
# dtype: int64

# %%
# subset dataset and split 
country = df.loc[df.country.notnull(), 'country'].astype('str').apply(lambda t: t.split(', '))

# Convert DataFrame column into list of strings
country = list(country)

# number of movies/TV shows without null values
len(country)
# Out:
# 767
